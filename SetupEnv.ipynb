# %%
import gym
import minihack
from utilities import render_des_file

# %%
env = gym.make(
       "MiniHack-Quest-Hard-v0",
)

# %%
env.reset()
env.render()
# Out:
# Hello Agent, welcome to NetHack!  You are a neutral human Caveman.
#
#
#
#
#
#             ##
#             @
#            ###
#
#
#
#
#
#
#
#
#
#
#
#
#
# Agent the Troglodyte           St:18/02 Dx:14 Co:17 In:8 Wi:8 Ch:8 Neutral S:0
# Dlvl:1 $:0 HP:16(16) Pw:2(2) AC:8 Xp:1/0
